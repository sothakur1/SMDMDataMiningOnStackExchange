# %% [markdown]
# ### UNCOVERING PATTERNS IN STACK EXCHANGE DATA

# %% [markdown]
# Arlene D’costa aadcosta@syr.edu
#
# Samyuktha Chaparla schaparl@syr.edu
#
# Sohan Thakur sothakur@syr.edu
#
# Krunal Gaikwad kgaikwad@syr.edu

# %%
import pdb
from nltk.corpus import stopwords, twitter_samples
import numpy as np
import pandas as pd
import nltk
import string
import os
from nltk.tokenize import TweetTokenizer
from os import getcwd
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
import json
import re
from nltk.corpus import wordnet
from collections import Counter
cnt = Counter()
import importlib
from nltk.corpus import words
import gensim
import gensim.corpora as corpora
from gensim.models import LdaModel
from gensim.models import CoherenceModel
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import sys
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, confusion_matrix
from sklearn.preprocessing import MaxAbsScaler
from sklearn.impute import SimpleImputer
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
path =  "/content/drive/MyDrive/SMDM"

# %%
nltk.download('words')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
sys.path.insert(0, f'{path}')

# %%
import technicalcorpus

# %%
test = importlib.reload(technicalcorpus)

# %%
english_words = set(words.words())
english_words = english_words.union(test.technical_terms)

# %%
STOPWORDS = set(stopwords.words('english'))

# %%
#Convert to lower
PUNCT_TO_REMOVE = string.punctuation

def remove_stopwords(text):
    """custom function to remove the stopwords"""
    return "  ".join([word for word in str(text).split() if word not in STOPWORDS])


def filter_non_english_words(text):
    words_list = text.split()
    english_words_list = [word for word in words_list if word.lower() in english_words]
    return ' '.join(english_words_list)

lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

stemmer = PorterStemmer()
def stem_words(text):
    return " ".join([stemmer.stem(word) for word in text.split()])

# %%
def remove_urls_punct(text):
        url_pattern = re.compile(r'https?://\S+|www\.\S+')
        url_new = re.compile(r'<.*?>')
        url_punc = re.compile(r",|'|#|\$|&|^|\.|!")
        text = url_pattern.sub(r' ', text)
        text = url_punc.sub(r' ', text)
        return url_new.sub(r' ', text)

# %% [markdown]
# Read post1.csv picked from Internet Archive website for Stack Exchange

# %%
post1df = pd.read_csv(f'{path}/post1.csv')
post1df = post1df.rename(columns=lambda x: x.replace('Attribute:', '') if x.startswith('Attribute:') else x)
post1dfpost1df = post1df.rename(columns=lambda x: x.replace('_', '') if x.startswith('_') else x)

# %%
post1df.head()
# Out:
#   Id PostTypeId      CreationDate Score ViewCount  \
# 0  1          1  23-05-2023 14:25     7       101
# 1  2          2  23-05-2023 14:44     3       NaN
# 2  3          2  23-05-2023 15:03     7       NaN
# 3  4          1  23-05-2023 15:10    13       199
# 4  5          1  23-05-2023 15:11    13       165
#
#                                                 Body OwnerUserId  \
# 0  <p>This site, as an education site with educat...          12
# 1  <p>Kmeans is used a lot of lately for clusteri...           7
# 2  <p>There's a notable difference between a ques...          23
# 3  <p>What is the best way of tagging questions t...          41
# 4  <p>On CS stack exchange, they use <code>$</cod...          27
#
#    LastActivityDate                         Title  \
# 0  23-05-2023 19:22     Objectivity and this site
# 1  23-05-2023 14:44                           NaN
# 2  23-05-2023 19:22                           NaN
# 3  23-06-2023 00:31       Suitable age range tags
# 4  26-05-2023 05:13  Can we enable math notation?
#
#                                  Tags  ...  ParentId  LastEditorUserId  \
# 0                        |discussion|  ...       NaN               NaN
# 1                                 NaN  ...       1.0               NaN
# 2                                 NaN  ...       1.0              23.0
# 3                   |discussion|tags|  ...       NaN               NaN
# 4  |feature-request|status-completed|  ...       NaN              23.0
#
#        LastEditDate  FavoriteCount  AcceptedAnswerId OwnerDisplayName  \
# 0               NaN            NaN               NaN              NaN
# 1               NaN            NaN               NaN              NaN
# 2  23-05-2023 19:22            NaN               NaN              NaN
# 3               NaN            NaN               NaN              NaN
# 4  26-05-2023 05:13            0.0               NaN              NaN
#
#    LastEditorDisplayName  CommunityOwnedDate ClosedDate DeletionDate
# 0                    NaN                 NaN        NaN          NaN
# 1                    NaN                 NaN        NaN          NaN
# 2                    NaN                 NaN        NaN          NaN
# 3                    NaN                 NaN        NaN          NaN
# 4                    NaN                 NaN        NaN          NaN
#
# [5 rows x 23 columns]

# %%
post1df.columns
# Out:
# Index(['Id', 'PostTypeId', 'CreationDate', 'Score', 'ViewCount', 'Body',
#        'OwnerUserId', 'LastActivityDate', 'Title', 'Tags', 'AnswerCount',
#        'CommentCount', 'ContentLicense', 'ParentId', 'LastEditorUserId',
#        'LastEditDate', 'FavoriteCount', 'AcceptedAnswerId', 'OwnerDisplayName',
#        'LastEditorDisplayName', 'CommunityOwnedDate', 'ClosedDate',
#        'DeletionDate'],
#       dtype='object')

# %%
post1df['Body']
# Out:
# 0      <p>This site, as an education site with educat...
# 1      <p>Kmeans is used a lot of lately for clusteri...
# 2      <p>There's a notable difference between a ques...
# 3      <p>What is the best way of tagging questions t...
# 4      <p>On CS stack exchange, they use <code>$</cod...
#                              ...
# 555    <p>As you all know, advertising is an importan...
# 556    <p>When I try to write mark-down language tabl...
# 557    <p>Many image files on <a href="https://en.wik...
# 558    <p>We received our first question about specif...
# 559    \n<p>It’s that time of the year again! As we w...
# Name: Body, Length: 560, dtype: object

# %%
post1df["Body"] = post1df["Body"].str.lower().fillna('')

post1df["textcleant"] = post1df["Body"].apply(lambda text: remove_urls_punct(text))
post1df["textcleant"] = post1df["textcleant"].apply(lambda text: lemmatize_words(text)).apply(lambda text:remove_stopwords(text))

# %%
post1df['textcleant']
# Out:
# 0      site  education  site  educator  bert  compute...
# 1      kmeans  used  lot  lately  clustering  general...
# 2      notable  difference  question  answered  defin...
# 3      best  way  tagging  question  identify  combin...
# 4      c  stack  exchange  use  enable  latex  math  ...
#                              ...
# 555    know  advertising  important  source  revenue ...
# 556    try  write  mark-down  language  table  line  ...
# 557    many  image  file  wikipedia  vector  graphic ...
# 558    received  first  question  specific  instituti...
# 559    it’s  time  year  wave  goodbye  last  year  w...
# Name: textcleant, Length: 560, dtype: object

# %%
newdf = post1df.copy()

# %%
newdf['features'] = newdf['textcleant'].apply(lambda x: filter_non_english_words(x))
newdf['features'] = newdf['features'].fillna('')

# %%
newdf['features']
# Out:
# 0      site education site educator bert end soliciti...
# 1      used lot lately clustering generally yes lot s...
# 2      notable difference question definitively eleme...
# 3      best way question identify combination experie...
# 4      c stack exchange use enable latex math stateme...
#                              ...
# 555    know advertising important source revenue stac...
# 556    try write language table line break usually in...
# 557    many image file vector graphic file computer_s...
# 558    received first question specific institution q...
# 559    time year wave last year welcome new one might...
# Name: features, Length: 560, dtype: object

# %%
# Convert 'score' column to numeric, ignoring errors
newdf['Score'] = pd.to_numeric(newdf['Score'], errors='coerce')

# Replace NaN values with the median of the 'score' column
newdf['Score'].fillna(newdf['Score'].median(), inplace=True)

# %% [markdown]
# Split the Dataset into Training and Testing subsets

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Step 1: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(newdf['features'], newdf['Score'], test_size=0.2, random_state=42)

# %%
# Step 2: Vectorize the text data

tfidf_vectorizer = TfidfVectorizer(lowercase=True, ngram_range=(1, 1))
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# %% [markdown]
# Linear Regression

# %%
# Step 3: Train a regression model
model = LinearRegression()
model.fit(X_train_tfidf, y_train)
# Out:
# LinearRegression()

# %%
#Predict upvote scores for test data
y_pred = model.predict(X_test_tfidf)
predictions = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
# Round the predicted values to the nearest integer
predictions['Predicted'] = predictions['Predicted'].round().astype(int)

print("\nPredictions:")
print(predictions)
# Out:
# Predictions:
#      Actual  Predicted
# 453     6.0          3
# 341     1.0          3
# 177     0.0          0
# 86      1.0          1
# 332     4.0          1
# ..      ...        ...
# 88      0.0          4
# 235     5.0          3
# 352     0.0          1
# 33      6.0          6
# 404     1.0          1
#
# [112 rows x 2 columns]

# %%
#Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 9.139151341177467

# %%
thresholds = [5,10,15,20]  # Define your own thresholds here

# Step 9: Categorize predicted upvote scores into bins
y_test_categories = pd.cut(y_test, bins=[-np.inf] + thresholds + [np.inf], labels=[f'<= {t}' for t in thresholds] + ['> max_threshold'])
y_pred_categories = pd.cut(y_pred, bins=[-np.inf] + thresholds + [np.inf], labels=[f'<= {t}' for t in thresholds] + ['> max_threshold'])

# Step 10: Calculate confusion matrix
conf_matrix = confusion_matrix(y_test_categories, y_pred_categories)

print("\nConfusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[ 3  0 14  0]
#  [ 0  0  1  0]
#  [ 6  0 87  0]
#  [ 1  0  0  0]]

# %% [markdown]
# Using Neural Networks Model

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
from tensorflow.keras import layers

# Impute missing values in the target variable (if any)
imputer = SimpleImputer(strategy='median')
y_train_imputed = imputer.fit_transform(y_train.values.reshape(-1, 1)).flatten()

# %%
X_tfidf = tfidf_vectorizer.fit_transform(newdf['features'])
y_score = newdf['Score']

# %%
# Split the data into training, validation, and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y_score, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# Convert the sparse matrices to dense matrices
X_train_dense = X_train.toarray()
X_val_dense = X_val.toarray()
X_test_dense = X_test.toarray()

# %%
#Impute missing values in the target variable (if any)
imputer = SimpleImputer(strategy='median')
y_train_imputed = imputer.fit_transform(y_train.values.reshape(-1, 1)).flatten()
y_val_imputed = imputer.transform(y_val.values.reshape(-1, 1)).flatten()

# %%
from keras import layers, regularizers
# neural network model
model = keras.Sequential([
    layers.Dense(32, activation='relu',kernel_regularizer=regularizers.l2(0.001), input_shape=[X_train_dense.shape[1]]),
    layers.Dropout(0.7),  # Dropout layer to reduce overfitting
    layers.Dense(16, activation='relu',kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),  # Dropout layer to reduce overfitting
    layers.Dense(1)
])

#Compile the model
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Step 8: Train the model
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train_dense, y_train_imputed, epochs=120, batch_size=32, validation_data=(X_val_dense, y_val_imputed))
# Out:
# Epoch 1/120
# 12/12 [==============================] - 3s 59ms/step - loss: 13.2296 - mae: 2.5412 - val_loss: 12.7371 - val_mae: 2.4248
# Epoch 2/120
# 12/12 [==============================] - 0s 13ms/step - loss: 12.7456 - mae: 2.4868 - val_loss: 12.2178 - val_mae: 2.3610
# Epoch 3/120
# 12/12 [==============================] - 0s 15ms/step - loss: 12.1696 - mae: 2.4134 - val_loss: 11.6054 - val_mae: 2.2784
# Epoch 4/120
# 12/12 [==============================] - 0s 14ms/step - loss: 11.3925 - mae: 2.3124 - val_loss: 10.9411 - val_mae: 2.1799
# Epoch 5/120
# 12/12 [==============================] - 0s 13ms/step - loss: 10.7383 - mae: 2.2037 - val_loss: 10.1896 - val_mae: 2.0563
# Epoch 6/120
# 12/12 [==============================] - 0s 16ms/step - loss: 9.8582 - mae: 2.0982 - val_loss: 9.4594 - val_mae: 1.9732
# Epoch 7/120
# 12/12 [==============================] - 0s 22ms/step - loss: 9.0298 - mae: 1.9935 - val_loss: 8.8223 - val_mae: 1.9305
# Epoch 8/120
# 12/12 [==============================] - 0s 20ms/step - loss: 8.1959 - mae: 1.9509 - val_loss: 8.3526 - val_mae: 1.9143
# Epoch 9/120
# 12/12 [==============================] - 0s 16ms/step - loss: 7.9462 - mae: 1.8859 - val_loss: 8.1221 - val_mae: 1.9165
# Epoch 10/120
# 12/12 [==============================] - 0s 18ms/step - loss: 8.1184 - mae: 1.9472 - val_loss: 7.9985 - val_mae: 1.9227
# Epoch 11/120
# 12/12 [==============================] - 0s 19ms/step - loss: 7.5759 - mae: 1.8138 - val_loss: 7.9238 - val_mae: 1.9260
# Epoch 12/120
# 12/12 [==============================] - 0s 21ms/step - loss: 7.4949 - mae: 1.8868 - val_loss: 7.8442 - val_mae: 1.9366
# Epoch 13/120
# 12/12 [==============================] - 0s 19ms/step - loss: 7.2522 - mae: 1.8385 - val_loss: 7.8069 - val_mae: 1.9294
# Epoch 14/120
# 12/12 [==============================] - 0s 12ms/step - loss: 7.4766 - mae: 1.8652 - val_loss: 7.8055 - val_mae: 1.9180
# Epoch 15/120
# 12/12 [==============================] - 0s 12ms/step - loss: 7.0887 - mae: 1.7722 - val_loss: 7.7720 - val_mae: 1.9134
# Epoch 16/120
# 12/12 [==============================] - 0s 12ms/step - loss: 6.8117 - mae: 1.7730 - val_loss: 7.7385 - val_mae: 1.9119
# Epoch 17/120
# 12/12 [==============================] - 0s 12ms/step - loss: 6.3340 - mae: 1.7112 - val_loss: 7.7016 - val_mae: 1.9124
# Epoch 18/120
# 12/12 [==============================] - 0s 12ms/step - loss: 7.1756 - mae: 1.8198 - val_loss: 7.6786 - val_mae: 1.9110
# Epoch 19/120
# 12/12 [==============================] - 0s 13ms/step - loss: 5.9224 - mae: 1.6696 - val_loss: 7.6490 - val_mae: 1.9103
# Epoch 20/120
# 12/12 [==============================] - 0s 11ms/step - loss: 6.1785 - mae: 1.6379 - val_loss: 7.6095 - val_mae: 1.9179
# Epoch 21/120
# 12/12 [==============================] - 0s 12ms/step - loss: 5.9060 - mae: 1.5883 - val_loss: 7.5688 - val_mae: 1.9190
# Epoch 22/120
# 12/12 [==============================] - 0s 14ms/step - loss: 6.4355 - mae: 1.6639 - val_loss: 7.5214 - val_mae: 1.9183
# Epoch 23/120
# 12/12 [==============================] - 0s 13ms/step - loss: 5.5716 - mae: 1.5830 - val_loss: 7.4876 - val_mae: 1.9171
# Epoch 24/120
# 12/12 [==============================] - 0s 13ms/step - loss: 5.1463 - mae: 1.5245 - val_loss: 7.4555 - val_mae: 1.9290
# Epoch 25/120
# 12/12 [==============================] - 0s 13ms/step - loss: 5.3452 - mae: 1.5258 - val_loss: 7.4385 - val_mae: 1.9169
# Epoch 26/120
# 12/12 [==============================] - 0s 12ms/step - loss: 5.7926 - mae: 1.5154 - val_loss: 7.4165 - val_mae: 1.9113
# Epoch 27/120
# 12/12 [==============================] - 0s 13ms/step - loss: 5.1122 - mae: 1.5073 - val_loss: 7.3946 - val_mae: 1.9054
# Epoch 28/120
# 12/12 [==============================] - 0s 12ms/step - loss: 4.4622 - mae: 1.3579 - val_loss: 7.3558 - val_mae: 1.9177
# Epoch 29/120
# 12/12 [==============================] - 0s 14ms/step - loss: 5.0427 - mae: 1.4457 - val_loss: 7.3214 - val_mae: 1.9236
# Epoch 30/120
# 12/12 [==============================] - 0s 14ms/step - loss: 4.5484 - mae: 1.4174 - val_loss: 7.3003 - val_mae: 1.9132
# Epoch 31/120
# 12/12 [==============================] - 0s 16ms/step - loss: 4.5343 - mae: 1.3992 - val_loss: 7.2931 - val_mae: 1.9038
# Epoch 32/120
# 12/12 [==============================] - 0s 12ms/step - loss: 4.4658 - mae: 1.3849 - val_loss: 7.2846 - val_mae: 1.8940
# Epoch 33/120
# 12/12 [==============================] - 0s 12ms/step - loss: 4.5809 - mae: 1.3726 - val_loss: 7.2526 - val_mae: 1.8985
# Epoch 34/120
# 12/12 [==============================] - 0s 13ms/step - loss: 4.0137 - mae: 1.3041 - val_loss: 7.2333 - val_mae: 1.9064
# Epoch 35/120
# 12/12 [==============================] - 0s 11ms/step - loss: 4.1353 - mae: 1.3399 - val_loss: 7.2493 - val_mae: 1.9322
# Epoch 36/120
# 12/12 [==============================] - 0s 13ms/step - loss: 4.4873 - mae: 1.3269 - val_loss: 7.2638 - val_mae: 1.9214
# Epoch 37/120
# 12/12 [==============================] - 0s 13ms/step - loss: 3.8404 - mae: 1.2284 - val_loss: 7.2502 - val_mae: 1.9199
# Epoch 38/120
# 12/12 [==============================] - 0s 10ms/step - loss: 3.7725 - mae: 1.2483 - val_loss: 7.2146 - val_mae: 1.9151
# Epoch 39/120
# 12/12 [==============================] - 0s 12ms/step - loss: 4.3955 - mae: 1.3148 - val_loss: 7.1918 - val_mae: 1.8965
# Epoch 40/120
# 12/12 [==============================] - 0s 12ms/step - loss: 3.5899 - mae: 1.2514 - val_loss: 7.2004 - val_mae: 1.8855
# Epoch 41/120
# 12/12 [==============================] - 0s 12ms/step - loss: 3.3478 - mae: 1.1708 - val_loss: 7.2048 - val_mae: 1.8817
# Epoch 42/120
# 12/12 [==============================] - 0s 11ms/step - loss: 3.8947 - mae: 1.2697 - val_loss: 7.1549 - val_mae: 1.9042
# Epoch 43/120
# 12/12 [==============================] - 0s 12ms/step - loss: 3.6667 - mae: 1.2936 - val_loss: 7.1532 - val_mae: 1.9344
# Epoch 44/120
# 12/12 [==============================] - 0s 12ms/step - loss: 3.8473 - mae: 1.3269 - val_loss: 7.1667 - val_mae: 1.9183
# Epoch 45/120
# 12/12 [==============================] - 0s 12ms/step - loss: 3.5355 - mae: 1.2301 - val_loss: 7.1663 - val_mae: 1.9155
# Epoch 46/120
# 12/12 [==============================] - 0s 12ms/step - loss: 3.5448 - mae: 1.1718 - val_loss: 7.1360 - val_mae: 1.9174
# Epoch 47/120
# 12/12 [==============================] - 0s 12ms/step - loss: 3.2524 - mae: 1.1567 - val_loss: 7.1261 - val_mae: 1.9125
# Epoch 48/120
# 12/12 [==============================] - 0s 12ms/step - loss: 3.5852 - mae: 1.2475 - val_loss: 7.0892 - val_mae: 1.9013
# Epoch 49/120
# 12/12 [==============================] - 0s 11ms/step - loss: 3.5425 - mae: 1.1634 - val_loss: 7.0519 - val_mae: 1.9053
# Epoch 50/120
# 12/12 [==============================] - 0s 13ms/step - loss: 3.5332 - mae: 1.2129 - val_loss: 7.0658 - val_mae: 1.9164
# Epoch 51/120
# 12/12 [==============================] - 0s 13ms/step - loss: 4.5086 - mae: 1.2349 - val_loss: 7.1216 - val_mae: 1.8935
# Epoch 52/120
# 12/12 [==============================] - 0s 13ms/step - loss: 3.7238 - mae: 1.1484 - val_loss: 7.1631 - val_mae: 1.8905
# Epoch 53/120
# 12/12 [==============================] - 0s 11ms/step - loss: 3.3907 - mae: 1.1613 - val_loss: 7.1386 - val_mae: 1.9127
# Epoch 54/120
# 12/12 [==============================] - 0s 14ms/step - loss: 3.5489 - mae: 1.2079 - val_loss: 7.1266 - val_mae: 1.9267
# Epoch 55/120
# 12/12 [==============================] - 0s 12ms/step - loss: 3.5309 - mae: 1.1643 - val_loss: 7.1006 - val_mae: 1.8995
# Epoch 56/120
# 12/12 [==============================] - 0s 14ms/step - loss: 2.8580 - mae: 1.1354 - val_loss: 7.0992 - val_mae: 1.8997
# Epoch 57/120
# 12/12 [==============================] - 0s 13ms/step - loss: 2.8429 - mae: 1.0999 - val_loss: 7.1015 - val_mae: 1.8991
# Epoch 58/120
# 12/12 [==============================] - 0s 8ms/step - loss: 3.4552 - mae: 1.1941 - val_loss: 7.1045 - val_mae: 1.9069
# Epoch 59/120
# 12/12 [==============================] - 0s 9ms/step - loss: 3.3674 - mae: 1.1709 - val_loss: 7.1265 - val_mae: 1.9188
# Epoch 60/120
# 12/12 [==============================] - 0s 9ms/step - loss: 2.7164 - mae: 1.0851 - val_loss: 7.1130 - val_mae: 1.9227
# Epoch 61/120
# 12/12 [==============================] - 0s 8ms/step - loss: 3.4169 - mae: 1.1987 - val_loss: 7.0957 - val_mae: 1.9246
# Epoch 62/120
# 12/12 [==============================] - 0s 9ms/step - loss: 2.9577 - mae: 1.1173 - val_loss: 7.0726 - val_mae: 1.9097
# Epoch 63/120
# 12/12 [==============================] - 0s 9ms/step - loss: 3.0436 - mae: 1.0674 - val_loss: 7.0859 - val_mae: 1.8959
# Epoch 64/120
# 12/12 [==============================] - 0s 8ms/step - loss: 2.8970 - mae: 1.1445 - val_loss: 7.0922 - val_mae: 1.8986
# Epoch 65/120
# 12/12 [==============================] - 0s 7ms/step - loss: 3.1917 - mae: 1.1355 - val_loss: 7.0709 - val_mae: 1.9098
# Epoch 66/120
# 12/12 [==============================] - 0s 8ms/step - loss: 3.0356 - mae: 1.1314 - val_loss: 7.0745 - val_mae: 1.8928
# Epoch 67/120
# 12/12 [==============================] - 0s 7ms/step - loss: 3.1712 - mae: 1.1326 - val_loss: 7.0513 - val_mae: 1.8918
# Epoch 68/120
# 12/12 [==============================] - 0s 9ms/step - loss: 3.0521 - mae: 1.0837 - val_loss: 7.1271 - val_mae: 1.8708
# Epoch 69/120
# 12/12 [==============================] - 0s 8ms/step - loss: 3.3611 - mae: 1.1135 - val_loss: 7.0780 - val_mae: 1.8872
# Epoch 70/120
# 12/12 [==============================] - 0s 9ms/step - loss: 2.9920 - mae: 1.0949 - val_loss: 7.0680 - val_mae: 1.9129
# Epoch 71/120
# 12/12 [==============================] - 0s 10ms/step - loss: 3.4880 - mae: 1.1470 - val_loss: 7.0647 - val_mae: 1.9307
# Epoch 72/120
# 12/12 [==============================] - 0s 9ms/step - loss: 3.4255 - mae: 1.1586 - val_loss: 7.0675 - val_mae: 1.9155
# Epoch 73/120
# 12/12 [==============================] - 0s 8ms/step - loss: 2.8946 - mae: 1.1239 - val_loss: 7.0712 - val_mae: 1.8818
# Epoch 74/120
# 12/12 [==============================] - 0s 8ms/step - loss: 2.7185 - mae: 1.1016 - val_loss: 7.0270 - val_mae: 1.8882
# Epoch 75/120
# 12/12 [==============================] - 0s 8ms/step - loss: 3.1558 - mae: 1.1128 - val_loss: 7.0359 - val_mae: 1.9005
# Epoch 76/120
# 12/12 [==============================] - 0s 8ms/step - loss: 2.9901 - mae: 1.1113 - val_loss: 7.0205 - val_mae: 1.9082
# Epoch 77/120
# 12/12 [==============================] - 0s 7ms/step - loss: 2.7074 - mae: 1.0503 - val_loss: 7.0410 - val_mae: 1.9020
# Epoch 78/120
# 12/12 [==============================] - 0s 7ms/step - loss: 3.4703 - mae: 1.1827 - val_loss: 7.0692 - val_mae: 1.8968
# Epoch 79/120
# 12/12 [==============================] - 0s 8ms/step - loss: 3.4191 - mae: 1.1461 - val_loss: 7.0618 - val_mae: 1.9113
# Epoch 80/120
# 12/12 [==============================] - 0s 7ms/step - loss: 3.1201 - mae: 1.1512 - val_loss: 7.0890 - val_mae: 1.9038
# Epoch 81/120
# 12/12 [==============================] - 0s 9ms/step - loss: 2.5951 - mae: 1.0781 - val_loss: 7.1136 - val_mae: 1.9102
# Epoch 82/120
# 12/12 [==============================] - 0s 10ms/step - loss: 3.4305 - mae: 1.1230 - val_loss: 7.1330 - val_mae: 1.9215
# Epoch 83/120
# 12/12 [==============================] - 0s 8ms/step - loss: 3.0652 - mae: 1.0612 - val_loss: 7.1684 - val_mae: 1.9053
# Epoch 84/120
# 12/12 [==============================] - 0s 8ms/step - loss: 3.1188 - mae: 1.0796 - val_loss: 7.1795 - val_mae: 1.9049
# Epoch 85/120
# 12/12 [==============================] - 0s 7ms/step - loss: 3.1823 - mae: 1.1652 - val_loss: 7.2081 - val_mae: 1.8919
# Epoch 86/120
# 12/12 [==============================] - 0s 7ms/step - loss: 3.1447 - mae: 1.1525 - val_loss: 7.1697 - val_mae: 1.8962
# Epoch 87/120
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6601 - mae: 1.0342 - val_loss: 7.1347 - val_mae: 1.9168
# Epoch 88/120
# 12/12 [==============================] - 0s 9ms/step - loss: 3.3560 - mae: 1.1203 - val_loss: 7.1592 - val_mae: 1.9103
# Epoch 89/120
# 12/12 [==============================] - 0s 8ms/step - loss: 2.7001 - mae: 1.0590 - val_loss: 7.1830 - val_mae: 1.9057
# Epoch 90/120
# 12/12 [==============================] - 0s 9ms/step - loss: 2.9705 - mae: 1.0949 - val_loss: 7.1858 - val_mae: 1.8924
# Epoch 91/120
# 12/12 [==============================] - 0s 10ms/step - loss: 3.0395 - mae: 1.0830 - val_loss: 7.1741 - val_mae: 1.8996
# Epoch 92/120
# 12/12 [==============================] - 0s 8ms/step - loss: 3.1656 - mae: 1.1241 - val_loss: 7.2006 - val_mae: 1.8861
# Epoch 93/120
# 12/12 [==============================] - 0s 7ms/step - loss: 2.7913 - mae: 1.0701 - val_loss: 7.3120 - val_mae: 1.8709
# Epoch 94/120
# 12/12 [==============================] - 0s 8ms/step - loss: 3.4963 - mae: 1.1566 - val_loss: 7.2360 - val_mae: 1.8928
# Epoch 95/120
# 12/12 [==============================] - 0s 8ms/step - loss: 2.7980 - mae: 1.0861 - val_loss: 7.1638 - val_mae: 1.9237
# Epoch 96/120
# 12/12 [==============================] - 0s 10ms/step - loss: 3.0840 - mae: 1.1194 - val_loss: 7.1351 - val_mae: 1.9292
# Epoch 97/120
# 12/12 [==============================] - 0s 8ms/step - loss: 2.9005 - mae: 1.0799 - val_loss: 7.1603 - val_mae: 1.9033
# Epoch 98/120
# 12/12 [==============================] - 0s 7ms/step - loss: 3.6427 - mae: 1.1500 - val_loss: 7.3611 - val_mae: 1.8664
# Epoch 99/120
# 12/12 [==============================] - 0s 8ms/step - loss: 2.9261 - mae: 1.0962 - val_loss: 7.3255 - val_mae: 1.8776
# Epoch 100/120
# 12/12 [==============================] - 0s 8ms/step - loss: 3.0062 - mae: 1.0848 - val_loss: 7.2564 - val_mae: 1.8897
# Epoch 101/120
# 12/12 [==============================] - 0s 11ms/step - loss: 2.6178 - mae: 1.0291 - val_loss: 7.2099 - val_mae: 1.9017
# Epoch 102/120
# 12/12 [==============================] - 0s 9ms/step - loss: 3.0744 - mae: 1.1080 - val_loss: 7.1757 - val_mae: 1.9178
# Epoch 103/120
# 12/12 [==============================] - 0s 9ms/step - loss: 2.8357 - mae: 1.0563 - val_loss: 7.1585 - val_mae: 1.9199
# Epoch 104/120
# 12/12 [==============================] - 0s 8ms/step - loss: 2.2812 - mae: 1.0435 - val_loss: 7.1900 - val_mae: 1.9004
# Epoch 105/120
# 12/12 [==============================] - 0s 8ms/step - loss: 3.9642 - mae: 1.1394 - val_loss: 7.2654 - val_mae: 1.8904
# Epoch 106/120
# 12/12 [==============================] - 0s 10ms/step - loss: 3.1606 - mae: 1.0985 - val_loss: 7.2288 - val_mae: 1.9032
# Epoch 107/120
# 12/12 [==============================] - 0s 9ms/step - loss: 2.6412 - mae: 1.0830 - val_loss: 7.1852 - val_mae: 1.9246
# Epoch 108/120
# 12/12 [==============================] - 0s 8ms/step - loss: 2.5681 - mae: 1.0593 - val_loss: 7.1629 - val_mae: 1.9435
# Epoch 109/120
# 12/12 [==============================] - 0s 9ms/step - loss: 2.7760 - mae: 1.0477 - val_loss: 7.1857 - val_mae: 1.9585
# Epoch 110/120
# 12/12 [==============================] - 0s 10ms/step - loss: 2.7520 - mae: 1.0232 - val_loss: 7.2079 - val_mae: 1.9464
# Epoch 111/120
# 12/12 [==============================] - 0s 9ms/step - loss: 2.8794 - mae: 1.0633 - val_loss: 7.2178 - val_mae: 1.9302
# Epoch 112/120
# 12/12 [==============================] - 0s 9ms/step - loss: 2.6046 - mae: 1.0773 - val_loss: 7.1771 - val_mae: 1.9333
# Epoch 113/120
# 12/12 [==============================] - 0s 8ms/step - loss: 2.6228 - mae: 1.0361 - val_loss: 7.1811 - val_mae: 1.9385
# Epoch 114/120
# 12/12 [==============================] - 0s 13ms/step - loss: 3.1576 - mae: 1.0942 - val_loss: 7.1907 - val_mae: 1.9132
# Epoch 115/120
# 12/12 [==============================] - 0s 11ms/step - loss: 2.4439 - mae: 1.0262 - val_loss: 7.1867 - val_mae: 1.9101
# Epoch 116/120
# 12/12 [==============================] - 0s 14ms/step - loss: 2.3563 - mae: 1.0388 - val_loss: 7.1783 - val_mae: 1.9138
# Epoch 117/120
# 12/12 [==============================] - 0s 12ms/step - loss: 2.4712 - mae: 1.0164 - val_loss: 7.1452 - val_mae: 1.9292
# Epoch 118/120
# 12/12 [==============================] - 0s 12ms/step - loss: 2.8334 - mae: 1.0650 - val_loss: 7.1210 - val_mae: 1.9258
# Epoch 119/120
# 12/12 [==============================] - 0s 11ms/step - loss: 3.2423 - mae: 1.0641 - val_loss: 7.1138 - val_mae: 1.9280
# Epoch 120/120
# 12/12 [==============================] - 0s 11ms/step - loss: 2.1094 - mae: 0.9602 - val_loss: 7.1077 - val_mae: 1.9354

# %%
# Predict upvote scores for test data
y_pred = model.predict(X_test_dense)

# Round the predicted values to the nearest integer
y_pred_rounded = np.round(y_pred)

#Output predictions
predictions = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_rounded.flatten()})
print("\nPredictions:")
print(predictions)
# Out:
# 4/4 [==============================] - 0s 4ms/step
#
# Predictions:
#      Actual  Predicted
# 453     6.0        2.0
# 341     1.0        2.0
# 177     0.0        1.0
# 86      1.0        2.0
# 332     4.0        1.0
# ..      ...        ...
# 88      0.0        3.0
# 235     5.0        4.0
# 352     0.0        1.0
# 33      6.0        4.0
# 404     1.0        1.0
#
# [112 rows x 2 columns]

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred_rounded)
print("Mean Squared Error:", mse)

# Define thresholds to categorize predicted upvote scores into bins
thresholds = [10, 20, 30]

# Categorize predicted upvote scores into bins
y_test_categories = pd.cut(y_test, bins=[-np.inf] + thresholds + [np.inf], labels=[f'<= {t}' for t in thresholds] + ['> max_threshold'])
y_pred_categories = pd.cut(y_pred_rounded.flatten(), bins=[-np.inf] + thresholds + [np.inf], labels=[f'<= {t}' for t in thresholds] + ['> max_threshold'])

# Calculate confusion matrix
conf_matrix = confusion_matrix(y_test_categories, y_pred_categories)
print("\nConfusion Matrix:")
print(conf_matrix)
# Out:
# Mean Squared Error: 8.357142857142858
#
# Confusion Matrix:
# [[110   0   0]
#  [  1   0   0]
#  [  1   0   0]]

# %% [markdown]
# Random Forest Regressor

# %%
from sklearn.preprocessing import MaxAbsScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.ensemble import RandomForestRegressor

# Preprocess the data
X_tfidf = tfidf_vectorizer.fit_transform(newdf['features'])
y_score = newdf['Score']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y_score, test_size=0.2, random_state=42)

# Define the pipeline
pipeline = Pipeline([
    ('scaler', MaxAbsScaler()),
    ('imputer', SimpleImputer(strategy='median')),
    ('feature_selection', SelectKBest(score_func=f_regression)),
    ('model', RandomForestRegressor())
])

# Define hyperparameters for tuning
param_grid = {
    'feature_selection__k': [50, 100, 'all'],
    'model__n_estimators': [100, 200, 300,400],
    'model__max_depth': [None, 10, 20,30],
    'model__min_samples_split': [2, 5,7, 10]
}

# Perform grid search for hyperparameter tuning
grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

# Get the best model from grid search
best_model = grid_search.best_estimator_

# Evaluate the best model on the test set
y_pred = best_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Output predictions
predictions = pd.DataFrame({'Actual': y_test, 'Predicted':  y_pred_rounded.flatten()})
print("\nPredictions:")
print(predictions)

print("Best Model:", best_model)
# Out:
# Mean Squared Error: 8.96069395030847
#
# Predictions:
#      Actual  Predicted
# 453     6.0        2.0
# 341     1.0        2.0
# 177     0.0        1.0
# 86      1.0        2.0
# 332     4.0        1.0
# ..      ...        ...
# 88      0.0        2.0
# 235     5.0        3.0
# 352     0.0        1.0
# 33      6.0        4.0
# 404     1.0        1.0
#
# [112 rows x 2 columns]
# Best Model: Pipeline(steps=[('scaler', MaxAbsScaler()),
#                 ('imputer', SimpleImputer(strategy='median')),
#                 ('feature_selection',
#                  SelectKBest(k='all',
#                              score_func=<function f_regression at 0x7f623c16b250>)),
#                 ('model', RandomForestRegressor(min_samples_split=7))])
